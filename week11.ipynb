# %%
import yfinance as yf
import os
import mplfinance as mpf
import pandas as pd
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from PIL import Image

# %%
# 1. 從 yfinance 獲取 AAPL 股票數據
stock_symbol = "AAPL"
start_date = "2020-01-01"
end_date = "2024-11-26"

stock_data = yf.download(stock_symbol, start=start_date, end=end_date)
stock_data.to_csv("AAPL.csv")
print("AAPL 股價數據已儲存至 AAPL.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# AAPL 股價數據已儲存至 AAPL.csv

# %%
# 2. 每 10 天生成一張 K 線圖並儲存
output_dir = "week11_kline"
os.makedirs(output_dir, exist_ok=True)

N = 2  # 每張 K 線圖的天數
num_chunks = len(stock_data) // N + (1 if len(stock_data) % N > 0 else 0)

for i in range(num_chunks):
    start_idx = i * N
    end_idx = (i + 1) * N
    kline_data = stock_data.iloc[start_idx:end_idx]
    if kline_data.empty:
        continue

    save_path = os.path.join(output_dir, f"AAPL_kline_part_{i+1}.png")
    mpf.plot(
        kline_data,
        type="candle",
        style="charles",
        title=f"AAPL K-Line Part {i+1}",
        ylabel="Price",
        savefig=save_path,
    )
    print(f"K 線圖已儲存至: {save_path}")
# Out:
# K 線圖已儲存至: week11_kline/AAPL_kline_part_1.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_2.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_3.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_4.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_5.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_6.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_7.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_8.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_9.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_10.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_11.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_12.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_13.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_14.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_15.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_16.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_17.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_18.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_19.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_20.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_21.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_22.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_23.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_24.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_25.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_26.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_27.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_28.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_29.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_30.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_31.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_32.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_33.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_34.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_35.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_36.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_37.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_38.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_39.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_40.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_41.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_42.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_43.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_44.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_45.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_46.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_47.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_48.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_49.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_50.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_51.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_52.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_53.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_54.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_55.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_56.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_57.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_58.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_59.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_60.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_61.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_62.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_63.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_64.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_65.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_66.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_67.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_68.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_69.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_70.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_71.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_72.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_73.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_74.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_75.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_76.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_77.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_78.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_79.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_80.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_81.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_82.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_83.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_84.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_85.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_86.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_87.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_88.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_89.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_90.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_91.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_92.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_93.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_94.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_95.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_96.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_97.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_98.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_99.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_100.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_101.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_102.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_103.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_104.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_105.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_106.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_107.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_108.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_109.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_110.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_111.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_112.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_113.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_114.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_115.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_116.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_117.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_118.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_119.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_120.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_121.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_122.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_123.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_124.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_125.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_126.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_127.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_128.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_129.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_130.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_131.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_132.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_133.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_134.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_135.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_136.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_137.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_138.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_139.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_140.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_141.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_142.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_143.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_144.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_145.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_146.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_147.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_148.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_149.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_150.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_151.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_152.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_153.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_154.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_155.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_156.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_157.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_158.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_159.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_160.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_161.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_162.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_163.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_164.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_165.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_166.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_167.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_168.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_169.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_170.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_171.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_172.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_173.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_174.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_175.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_176.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_177.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_178.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_179.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_180.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_181.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_182.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_183.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_184.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_185.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_186.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_187.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_188.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_189.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_190.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_191.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_192.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_193.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_194.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_195.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_196.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_197.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_198.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_199.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_200.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_201.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_202.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_203.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_204.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_205.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_206.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_207.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_208.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_209.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_210.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_211.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_212.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_213.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_214.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_215.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_216.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_217.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_218.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_219.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_220.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_221.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_222.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_223.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_224.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_225.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_226.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_227.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_228.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_229.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_230.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_231.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_232.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_233.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_234.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_235.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_236.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_237.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_238.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_239.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_240.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_241.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_242.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_243.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_244.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_245.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_246.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_247.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_248.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_249.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_250.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_251.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_252.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_253.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_254.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_255.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_256.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_257.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_258.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_259.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_260.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_261.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_262.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_263.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_264.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_265.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_266.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_267.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_268.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_269.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_270.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_271.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_272.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_273.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_274.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_275.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_276.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_277.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_278.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_279.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_280.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_281.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_282.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_283.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_284.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_285.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_286.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_287.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_288.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_289.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_290.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_291.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_292.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_293.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_294.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_295.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_296.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_297.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_298.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_299.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_300.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_301.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_302.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_303.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_304.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_305.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_306.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_307.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_308.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_309.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_310.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_311.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_312.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_313.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_314.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_315.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_316.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_317.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_318.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_319.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_320.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_321.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_322.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_323.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_324.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_325.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_326.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_327.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_328.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_329.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_330.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_331.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_332.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_333.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_334.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_335.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_336.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_337.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_338.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_339.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_340.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_341.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_342.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_343.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_344.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_345.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_346.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_347.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_348.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_349.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_350.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_351.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_352.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_353.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_354.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_355.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_356.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_357.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_358.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_359.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_360.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_361.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_362.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_363.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_364.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_365.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_366.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_367.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_368.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_369.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_370.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_371.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_372.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_373.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_374.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_375.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_376.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_377.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_378.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_379.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_380.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_381.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_382.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_383.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_384.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_385.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_386.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_387.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_388.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_389.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_390.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_391.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_392.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_393.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_394.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_395.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_396.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_397.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_398.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_399.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_400.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_401.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_402.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_403.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_404.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_405.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_406.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_407.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_408.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_409.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_410.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_411.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_412.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_413.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_414.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_415.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_416.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_417.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_418.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_419.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_420.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_421.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_422.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_423.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_424.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_425.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_426.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_427.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_428.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_429.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_430.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_431.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_432.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_433.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_434.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_435.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_436.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_437.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_438.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_439.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_440.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_441.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_442.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_443.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_444.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_445.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_446.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_447.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_448.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_449.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_450.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_451.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_452.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_453.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_454.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_455.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_456.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_457.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_458.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_459.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_460.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_461.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_462.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_463.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_464.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_465.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_466.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_467.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_468.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_469.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_470.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_471.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_472.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_473.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_474.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_475.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_476.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_477.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_478.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_479.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_480.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_481.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_482.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_483.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_484.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_485.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_486.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_487.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_488.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_489.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_490.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_491.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_492.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_493.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_494.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_495.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_496.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_497.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_498.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_499.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_500.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_501.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_502.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_503.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_504.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_505.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_506.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_507.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_508.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_509.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_510.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_511.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_512.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_513.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_514.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_515.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_516.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_517.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_518.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_519.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_520.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_521.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_522.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_523.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_524.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_525.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_526.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_527.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_528.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_529.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_530.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_531.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_532.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_533.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_534.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_535.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_536.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_537.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_538.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_539.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_540.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_541.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_542.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_543.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_544.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_545.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_546.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_547.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_548.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_549.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_550.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_551.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_552.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_553.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_554.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_555.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_556.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_557.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_558.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_559.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_560.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_561.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_562.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_563.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_564.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_565.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_566.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_567.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_568.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_569.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_570.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_571.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_572.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_573.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_574.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_575.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_576.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_577.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_578.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_579.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_580.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_581.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_582.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_583.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_584.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_585.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_586.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_587.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_588.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_589.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_590.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_591.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_592.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_593.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_594.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_595.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_596.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_597.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_598.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_599.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_600.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_601.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_602.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_603.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_604.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_605.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_606.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_607.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_608.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_609.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_610.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_611.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_612.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_613.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_614.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_615.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_616.png
# K 線圖已儲存至: week11_kline/AAPL_kline_part_617.png

# %%
# 3. 新增圖片名稱和 Label 欄位到 CSV
stock_data["Image"] = ""
stock_data["Label"] = 0

for i in range(num_chunks):
    start_idx = i * N
    end_idx = min((i + 1) * N, len(stock_data))
    if end_idx - start_idx < 2:
        continue
    stock_data.iloc[start_idx:end_idx, stock_data.columns.get_loc("Image")] = f"AAPL_kline_part_{i+1}.png"
    start_close = stock_data.iloc[start_idx]["Close"]
    end_close = stock_data.iloc[end_idx - 1]["Close"]
    stock_data.iloc[end_idx - 1, stock_data.columns.get_loc("Label")] = int(end_close > start_close)

stock_data.to_csv("AAPL_labeled.csv")
print("新增 Image 和 Label 欄位後的數據已儲存至 AAPL_labeled.csv")
# Out:
# 新增 Image 和 Label 欄位後的數據已儲存至 AAPL_labeled.csv

# %%
# 4. 分割數據集
labeled_data = pd.read_csv("AAPL_labeled.csv")
train_data, temp_data = train_test_split(labeled_data, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

train_data.to_csv("AAPL_train.csv", index=False)
val_data.to_csv("AAPL_val.csv", index=False)
test_data.to_csv("AAPL_test.csv", index=False)

print(train_data['Label'].value_counts())
print(val_data['Label'].value_counts())


print(f"訓練集大小: {len(train_data)}")
print(f"驗證集大小: {len(val_data)}")
print(f"測試集大小: {len(test_data)}")
# Out:
# Label
# 0    652
# 1    211
# Name: count, dtype: int64
# Label
# 0    135
# 1     50
# Name: count, dtype: int64
# 訓練集大小: 863
# 驗證集大小: 185
# 測試集大小: 186

# %%
# 5. 定義數據集類
class MultiModalDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        self.data = pd.read_csv(csv_file)
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        structured_data = row[['Open', 'High', 'Low', 'Close', 'Volume']].values.astype(float)
        image_path = os.path.join(self.image_dir, f"{row['Image']}")
        image = Image.open(image_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        label = row['Label']
        return torch.tensor(structured_data, dtype=torch.float32), image, torch.tensor(label, dtype=torch.long)

# %%
# 6. 定義數據轉換和加載器
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

image_dir = "week11_kline"

train_dataset = MultiModalDataset("AAPL_train.csv", image_dir, transform=transform)
val_dataset = MultiModalDataset("AAPL_val.csv", image_dir, transform=transform)
test_dataset = MultiModalDataset("AAPL_test.csv", image_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# 7. 定義多模態模型
class MultiModalModel(nn.Module):
    def __init__(self, num_structured_features, num_classes):
        super(MultiModalModel, self).__init__()
        self.image_model = models.resnet18(pretrained=True)
        self.image_model.fc = nn.Identity()
        self.structured_fc = nn.Sequential(
            nn.Linear(num_structured_features, 128),
            nn.ReLU(),
            nn.Dropout(0.2)
        )
        self.fc = nn.Sequential(
            nn.Linear(512 + 128, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
    
    def forward(self, structured_data, images):
        image_features = self.image_model(images)
        structured_features = self.structured_fc(structured_data)
        combined_features = torch.cat((image_features, structured_features), dim=1)
        return self.fc(combined_features)

# %%
# 8. 初始化模型和訓練
model = MultiModalModel(num_structured_features=5, num_classes=2)
criterion = nn.CrossEntropyLoss(weight=torch.tensor([1.0, 5.0]).cuda())
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(10):
    model.train()
    for structured_data, images, labels in train_loader:
        if torch.cuda.is_available():
            model = model.cuda()
            structured_data = structured_data.cuda()
            images = images.cuda()
            labels = labels.cuda()
        outputs = model(structured_data, images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# /home/danielwang/miniconda3/envs/nchu_1131_finance/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/danielwang/miniconda3/envs/nchu_1131_finance/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1, Loss: 735942.0625
# Epoch 2, Loss: 467334.6250
# Epoch 3, Loss: 27402.7227
# Epoch 4, Loss: 10118.1836
# Epoch 5, Loss: 12812.3701
# Epoch 6, Loss: 2055.9563
# Epoch 7, Loss: 1161.1523
# Epoch 8, Loss: 430.0906
# Epoch 9, Loss: 293.5457
# Epoch 10, Loss: 277.5284

# %%
# 9. 驗證模型性能
model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for structured_data, images, labels in val_loader:
        if torch.cuda.is_available():
            structured_data, images, labels = structured_data.cuda(), images.cuda(), labels.cuda()
        outputs = model(structured_data, images)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds)
recall = recall_score(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds)

print(f"驗證集性能指標：\n準確率: {accuracy:.2f}\n精確率: {precision:.2f}\n召回率: {recall:.2f}\nF1 分數: {f1:.2f}")
# Out:
# 驗證集性能指標：
# 準確率: 0.27
# 精確率: 0.27
# 召回率: 1.00
# F1 分數: 0.43
